# %%
print('[Info]: Importing Libraries')

import numpy as np
import pandas as pd
import lightgbm as lgb
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
# Out:
# [Info]: Importing Libraries

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Helper Functions

def display_missing_data(data_frame):
    return data_frame.isnull().sum()/len(data_frame)*100

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
print('[Info]: Reading the Data\n')

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

((train_data.shape), (test_data.shape))
# Out:
# [Info]: Reading the Data
# ((85741, 133), (28580, 132))

# %%
print('[Info]: Separating Depending and Independent Varibales')

X_train = train_data.drop(columns=['target_label','IDs'],axis=1)
y = train_data['target_label']

X_tst = test_data.drop(columns=['IDs'],axis=1)
IDs = test_data['IDs']
IDs.to_csv('./ID.csv', index= False)

((X_train.shape), (y.shape), (X_tst.shape))
# Out:
# [Info]: Separating Depending and Independent Varibales
# ((85741, 131), (85741,), (28580, 131))

# %%
print('[Info]: Separating Numerical Data \n')

numerical_data_trn = X_train.select_dtypes(include = [np.number])
numerical_data_tst = X_tst.select_dtypes(include = [np.number])

((numerical_data_trn.shape), (numerical_data_tst.shape))
# Out:
# [Info]: Separating Numerical Data
# ((85741, 112), (28580, 112))

# %% [markdown]
# ### Removing Similar features based on correlaltion

# %%
corr_features = correlation(numerical_data_trn, 0.8)

# %%
X_train = numerical_data_trn.drop(labels = corr_features, axis=1)
X_test = numerical_data_tst.drop(labels = corr_features, axis=1)

X_train.shape, X_test.shape
# Out:
# ((85741, 54), (28580, 54))

# %%
X_train = X_train.fillna(-999)
X_test = X_test.fillna(-999)

# %% [markdown]
# ### Categorical Data Creation

# %%
# Separating Categorical Data

category_trn = train_data.select_dtypes(exclude=[np.number])
print('Shape of category train :', category_trn.shape)

category_tst = test_data.select_dtypes(exclude=[np.number])
print('Shape of category test :', category_tst.shape)
# Out:
# Shape of category train : (85741, 19)
# Shape of category test : (28580, 19)

# %%
category_trn = category_trn.drop(columns=['x52', 'x54', 'x56'],axis=1)
category_tst = category_tst.drop(columns=['x52', 'x54', 'x56'],axis=1)

# %%
category_trn = category_trn.fillna(category_trn.mode().iloc[0])
category_tst = category_tst.fillna(category_trn.mode().iloc[0])

category_trn.shape, category_tst.shape
# Out:
# ((85741, 16), (28580, 16))

# %%
# Creating Dummy Variable for Training Data
dummy_trn = pd.DataFrame()

for i in category_trn:
    dummy_trn = pd.concat([dummy_trn,
                           pd.get_dummies(data = category_trn[i], prefix = i,
                                          drop_first = True)], axis = 1)

# %%
# Creating Dummy Variable for Testing Data
dummy_tst = pd.DataFrame()

for i in category_trn:
    dummy_tst = pd.concat([dummy_tst, 
                           pd.get_dummies(data = category_tst[i], prefix = i,
                                          drop_first = True)], axis = 1)

# %%
if not (len(dummy_trn.columns) == len(dummy_tst.columns)):
    print(len(dummy_trn.columns), len(dummy_tst.columns))
    print('\ndummy variable length not equal' + '\n' +  'creating equal length\n')
    intesection = set(dummy_trn.columns).intersection(set(dummy_tst))
    dummy_trn = dummy_trn[intesection]
    dummy_tst = dummy_tst[intesection]
    print(len(dummy_trn.columns), len(dummy_tst.columns))
else:
    print('Train and Test Sets have equal number of dummy Variables')
# Out:
# 299 278
#
# dummy variable length not equal
# creating equal length
#
# 272 272

# %%
# Concatinating Numerical And Categorical Data

concat_trn = pd.concat([X_train, dummy_trn], axis = 1 )
concat_tst = pd.concat([X_test, dummy_tst], axis = 1 )

((concat_trn.shape), (concat_tst.shape))
# Out:
# ((85741, 326), (28580, 326))

# %% [markdown]
# #### Creating Model for Categorical Data

# %%
# Submission File
class ClassPredictLGBM:
    
    def predict_lbm(self, df_train, df_test, y):
        
        X_train, X_val, y_train, y_val = train_test_split(
            df_train, y, test_size = 0.3, random_state = 8)
        
        train_data = lgb.Dataset(X_train, label= y_train)
        val_data = lgb.Dataset(X_val, label= y_val)

        #setting parameters for lightgbm
        param = {'num_leaves':30, 'objective':'binary','max_depth':7,
                 'learning_rate':.05,'max_bin':50, 'metric':'binary_logloss',
                 'verbose': -1, 'lambda_l1' : 0.01}

        #training our model using light gbm
        num_round = 5000

        print('[Info]: Model is getting Trained ...')
        
        lgbm = lgb.train(param, train_set = train_data, num_boost_round = num_round,
                 valid_sets= val_data, verbose_eval = True, early_stopping_rounds = 100)
        
        print('[Info]: Model is predicting the Data ... \n')
        pred_prob = lgbm.predict(df_test)

        # Submission
        submission = pd.read_csv('./ID.csv')
        submission.index = submission.IDs
        submission['score'] = pred_prob.round(0)
        submission.to_csv('./shekhar_submission.csv', index=False)

        print('[Info]: Outputs are saved under shekhar_submission.csv file.')
        return


# Class and funtion calling to get prediction probabilities file.
a = ClassPredictLGBM()
a.predict_lbm(concat_trn, concat_tst, y)
# Out:
# [Info]: Model is getting Trained ...
# [1]	valid_0's binary_logloss: 0.542391
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.536374
# [3]	valid_0's binary_logloss: 0.531028
# [4]	valid_0's binary_logloss: 0.526264
# [5]	valid_0's binary_logloss: 0.521964
# [6]	valid_0's binary_logloss: 0.518069
# [7]	valid_0's binary_logloss: 0.514567
# [8]	valid_0's binary_logloss: 0.51122
# [9]	valid_0's binary_logloss: 0.508179
# [10]	valid_0's binary_logloss: 0.505388
# [11]	valid_0's binary_logloss: 0.502929
# [12]	valid_0's binary_logloss: 0.500678
# [13]	valid_0's binary_logloss: 0.498562
# [14]	valid_0's binary_logloss: 0.496593
# [15]	valid_0's binary_logloss: 0.494781
# [16]	valid_0's binary_logloss: 0.493181
# [17]	valid_0's binary_logloss: 0.491745
# [18]	valid_0's binary_logloss: 0.490353
# [19]	valid_0's binary_logloss: 0.489024
# [20]	valid_0's binary_logloss: 0.487835
# [21]	valid_0's binary_logloss: 0.486696
# [22]	valid_0's binary_logloss: 0.485645
# [23]	valid_0's binary_logloss: 0.484673
# [24]	valid_0's binary_logloss: 0.483762
# [25]	valid_0's binary_logloss: 0.482961
# [26]	valid_0's binary_logloss: 0.482185
# [27]	valid_0's binary_logloss: 0.481479
# [28]	valid_0's binary_logloss: 0.480914
# [29]	valid_0's binary_logloss: 0.480282
# [30]	valid_0's binary_logloss: 0.479705
# [31]	valid_0's binary_logloss: 0.479239
# [32]	valid_0's binary_logloss: 0.478721
# [33]	valid_0's binary_logloss: 0.478217
# [34]	valid_0's binary_logloss: 0.477733
# [35]	valid_0's binary_logloss: 0.477337
# [36]	valid_0's binary_logloss: 0.476903
# [37]	valid_0's binary_logloss: 0.47655
# [38]	valid_0's binary_logloss: 0.47622
# [39]	valid_0's binary_logloss: 0.475831
# [40]	valid_0's binary_logloss: 0.4756
# [41]	valid_0's binary_logloss: 0.475358
# [42]	valid_0's binary_logloss: 0.475049
# [43]	valid_0's binary_logloss: 0.474835
# [44]	valid_0's binary_logloss: 0.474667
# [45]	valid_0's binary_logloss: 0.474439
# [46]	valid_0's binary_logloss: 0.474226
# [47]	valid_0's binary_logloss: 0.47402
# [48]	valid_0's binary_logloss: 0.47385
# [49]	valid_0's binary_logloss: 0.47368
# [50]	valid_0's binary_logloss: 0.473526
# [51]	valid_0's binary_logloss: 0.473352
# [52]	valid_0's binary_logloss: 0.473183
# [53]	valid_0's binary_logloss: 0.472991
# [54]	valid_0's binary_logloss: 0.472824
# [55]	valid_0's binary_logloss: 0.472705
# [56]	valid_0's binary_logloss: 0.472567
# [57]	valid_0's binary_logloss: 0.472414
# [58]	valid_0's binary_logloss: 0.472348
# [59]	valid_0's binary_logloss: 0.472284
# [60]	valid_0's binary_logloss: 0.472223
# [61]	valid_0's binary_logloss: 0.472093
# [62]	valid_0's binary_logloss: 0.471974
# [63]	valid_0's binary_logloss: 0.471933
# [64]	valid_0's binary_logloss: 0.471857
# [65]	valid_0's binary_logloss: 0.471766
# [66]	valid_0's binary_logloss: 0.471738
# [67]	valid_0's binary_logloss: 0.471545
# [68]	valid_0's binary_logloss: 0.471399
# [69]	valid_0's binary_logloss: 0.471254
# [70]	valid_0's binary_logloss: 0.471139
# [71]	valid_0's binary_logloss: 0.471053
# [72]	valid_0's binary_logloss: 0.47099
# [73]	valid_0's binary_logloss: 0.470885
# [74]	valid_0's binary_logloss: 0.470867
# [75]	valid_0's binary_logloss: 0.47069
# [76]	valid_0's binary_logloss: 0.470644
# [77]	valid_0's binary_logloss: 0.470582
# [78]	valid_0's binary_logloss: 0.470535
# [79]	valid_0's binary_logloss: 0.470509
# [80]	valid_0's binary_logloss: 0.470464
# [81]	valid_0's binary_logloss: 0.470385
# [82]	valid_0's binary_logloss: 0.470331
# [83]	valid_0's binary_logloss: 0.470202
# [84]	valid_0's binary_logloss: 0.470184
# [85]	valid_0's binary_logloss: 0.470135
# [86]	valid_0's binary_logloss: 0.470078
# [87]	valid_0's binary_logloss: 0.470095
# [88]	valid_0's binary_logloss: 0.470073
# [89]	valid_0's binary_logloss: 0.470074
# [90]	valid_0's binary_logloss: 0.469949
# [91]	valid_0's binary_logloss: 0.469888
# [92]	valid_0's binary_logloss: 0.469893
# [93]	valid_0's binary_logloss: 0.469856
# [94]	valid_0's binary_logloss: 0.469767
# [95]	valid_0's binary_logloss: 0.469744
# [96]	valid_0's binary_logloss: 0.469705
# [97]	valid_0's binary_logloss: 0.469676
# [98]	valid_0's binary_logloss: 0.469564
# [99]	valid_0's binary_logloss: 0.469587
# [100]	valid_0's binary_logloss: 0.469622
# [101]	valid_0's binary_logloss: 0.469628
# [102]	valid_0's binary_logloss: 0.46965
# [103]	valid_0's binary_logloss: 0.469634
# [104]	valid_0's binary_logloss: 0.469601
# [105]	valid_0's binary_logloss: 0.469563
# [106]	valid_0's binary_logloss: 0.469592
# [107]	valid_0's binary_logloss: 0.469575
# [108]	valid_0's binary_logloss: 0.469527
# [109]	valid_0's binary_logloss: 0.469546
# [110]	valid_0's binary_logloss: 0.469545
# [111]	valid_0's binary_logloss: 0.469534
# [112]	valid_0's binary_logloss: 0.469536
# [113]	valid_0's binary_logloss: 0.469538
# [114]	valid_0's binary_logloss: 0.469513
# [115]	valid_0's binary_logloss: 0.469476
# [116]	valid_0's binary_logloss: 0.469458
# [117]	valid_0's binary_logloss: 0.469424
# [118]	valid_0's binary_logloss: 0.469407
# [119]	valid_0's binary_logloss: 0.469388
# [120]	valid_0's binary_logloss: 0.469366
# [121]	valid_0's binary_logloss: 0.469358
# [122]	valid_0's binary_logloss: 0.469356
# [123]	valid_0's binary_logloss: 0.469349
# [124]	valid_0's binary_logloss: 0.469314
# [125]	valid_0's binary_logloss: 0.46933
# [126]	valid_0's binary_logloss: 0.469328
# [127]	valid_0's binary_logloss: 0.469298
# [128]	valid_0's binary_logloss: 0.469265
# [129]	valid_0's binary_logloss: 0.469223
# [130]	valid_0's binary_logloss: 0.469199
# [131]	valid_0's binary_logloss: 0.469188
# [132]	valid_0's binary_logloss: 0.469169
# [133]	valid_0's binary_logloss: 0.469175
# [134]	valid_0's binary_logloss: 0.469155
# [135]	valid_0's binary_logloss: 0.469157
# [136]	valid_0's binary_logloss: 0.469194
# [137]	valid_0's binary_logloss: 0.469195
# [138]	valid_0's binary_logloss: 0.469174
# [139]	valid_0's binary_logloss: 0.469184
# [140]	valid_0's binary_logloss: 0.469158
# [141]	valid_0's binary_logloss: 0.469149
# [142]	valid_0's binary_logloss: 0.469152
# [143]	valid_0's binary_logloss: 0.469146
# [144]	valid_0's binary_logloss: 0.469118
# [145]	valid_0's binary_logloss: 0.469116
# [146]	valid_0's binary_logloss: 0.469127
# [147]	valid_0's binary_logloss: 0.469095
# [148]	valid_0's binary_logloss: 0.469054
# [149]	valid_0's binary_logloss: 0.469104
# [150]	valid_0's binary_logloss: 0.46908
# [151]	valid_0's binary_logloss: 0.469045
# [152]	valid_0's binary_logloss: 0.469048
# [153]	valid_0's binary_logloss: 0.468935
# [154]	valid_0's binary_logloss: 0.468958
# [155]	valid_0's binary_logloss: 0.468935
# [156]	valid_0's binary_logloss: 0.468926
# [157]	valid_0's binary_logloss: 0.468916
# [158]	valid_0's binary_logloss: 0.468896
# [159]	valid_0's binary_logloss: 0.4689
# [160]	valid_0's binary_logloss: 0.468894
# [161]	valid_0's binary_logloss: 0.468889
# [162]	valid_0's binary_logloss: 0.468878
# [163]	valid_0's binary_logloss: 0.468915
# [164]	valid_0's binary_logloss: 0.468899
# [165]	valid_0's binary_logloss: 0.468876
# [166]	valid_0's binary_logloss: 0.468845
# [167]	valid_0's binary_logloss: 0.468816
# [168]	valid_0's binary_logloss: 0.468774
# [169]	valid_0's binary_logloss: 0.468696
# [170]	valid_0's binary_logloss: 0.468717
# [171]	valid_0's binary_logloss: 0.468697
# [172]	valid_0's binary_logloss: 0.468736
# [173]	valid_0's binary_logloss: 0.468734
# [174]	valid_0's binary_logloss: 0.468748
# [175]	valid_0's binary_logloss: 0.468754
# [176]	valid_0's binary_logloss: 0.468741
# [177]	valid_0's binary_logloss: 0.468735
# [178]	valid_0's binary_logloss: 0.468717
# [179]	valid_0's binary_logloss: 0.468679
# [180]	valid_0's binary_logloss: 0.468672
# [181]	valid_0's binary_logloss: 0.468657
# [182]	valid_0's binary_logloss: 0.468613
# [183]	valid_0's binary_logloss: 0.468619
# [184]	valid_0's binary_logloss: 0.468616
# [185]	valid_0's binary_logloss: 0.468645
# [186]	valid_0's binary_logloss: 0.468612
# [187]	valid_0's binary_logloss: 0.468632
# [188]	valid_0's binary_logloss: 0.468619
# [189]	valid_0's binary_logloss: 0.4686
# [190]	valid_0's binary_logloss: 0.468515
# [191]	valid_0's binary_logloss: 0.468496
# [192]	valid_0's binary_logloss: 0.468464
# [193]	valid_0's binary_logloss: 0.468458
# [194]	valid_0's binary_logloss: 0.468476
# [195]	valid_0's binary_logloss: 0.468461
# [196]	valid_0's binary_logloss: 0.468458
# [197]	valid_0's binary_logloss: 0.46844
# [198]	valid_0's binary_logloss: 0.468436
# [199]	valid_0's binary_logloss: 0.468462
# [200]	valid_0's binary_logloss: 0.468454
# [201]	valid_0's binary_logloss: 0.468429
# [202]	valid_0's binary_logloss: 0.468419
# [203]	valid_0's binary_logloss: 0.46841
# [204]	valid_0's binary_logloss: 0.468423
# [205]	valid_0's binary_logloss: 0.468418
# [206]	valid_0's binary_logloss: 0.468431
# [207]	valid_0's binary_logloss: 0.468437
# [208]	valid_0's binary_logloss: 0.468422
# [209]	valid_0's binary_logloss: 0.468408
# [210]	valid_0's binary_logloss: 0.468413
# [211]	valid_0's binary_logloss: 0.468401
# [212]	valid_0's binary_logloss: 0.468426
# [213]	valid_0's binary_logloss: 0.468412
# [214]	valid_0's binary_logloss: 0.468385
# [215]	valid_0's binary_logloss: 0.4684
# [216]	valid_0's binary_logloss: 0.468408
# [217]	valid_0's binary_logloss: 0.46842
# [218]	valid_0's binary_logloss: 0.468422
# [219]	valid_0's binary_logloss: 0.468436
# [220]	valid_0's binary_logloss: 0.468396
# [221]	valid_0's binary_logloss: 0.468424
# [222]	valid_0's binary_logloss: 0.468393
# [223]	valid_0's binary_logloss: 0.468377
# [224]	valid_0's binary_logloss: 0.468366
# [225]	valid_0's binary_logloss: 0.468374
# [226]	valid_0's binary_logloss: 0.468389
# [227]	valid_0's binary_logloss: 0.468386
# [228]	valid_0's binary_logloss: 0.468397
# [229]	valid_0's binary_logloss: 0.468353
# [230]	valid_0's binary_logloss: 0.468341
# [231]	valid_0's binary_logloss: 0.46834
# [232]	valid_0's binary_logloss: 0.468329
# [233]	valid_0's binary_logloss: 0.468359
# [234]	valid_0's binary_logloss: 0.468288
# [235]	valid_0's binary_logloss: 0.468297
# [236]	valid_0's binary_logloss: 0.468297
# [237]	valid_0's binary_logloss: 0.468285
# [238]	valid_0's binary_logloss: 0.468325
# [239]	valid_0's binary_logloss: 0.468282
# [240]	valid_0's binary_logloss: 0.468281
# [241]	valid_0's binary_logloss: 0.468265
# [242]	valid_0's binary_logloss: 0.468264
# [243]	valid_0's binary_logloss: 0.468265
# [244]	valid_0's binary_logloss: 0.468285
# [245]	valid_0's binary_logloss: 0.468287
# [246]	valid_0's binary_logloss: 0.46827
# [247]	valid_0's binary_logloss: 0.468249
# [248]	valid_0's binary_logloss: 0.468233
# [249]	valid_0's binary_logloss: 0.468231
# [250]	valid_0's binary_logloss: 0.468228
# [251]	valid_0's binary_logloss: 0.468241
# [252]	valid_0's binary_logloss: 0.468213
# [253]	valid_0's binary_logloss: 0.468224
# [254]	valid_0's binary_logloss: 0.468214
# [255]	valid_0's binary_logloss: 0.468221
# [256]	valid_0's binary_logloss: 0.46816
# [257]	valid_0's binary_logloss: 0.468121
# [258]	valid_0's binary_logloss: 0.468102
# [259]	valid_0's binary_logloss: 0.468087
# [260]	valid_0's binary_logloss: 0.468102
# [261]	valid_0's binary_logloss: 0.468074
# [262]	valid_0's binary_logloss: 0.468088
# [263]	valid_0's binary_logloss: 0.468093
# [264]	valid_0's binary_logloss: 0.468104
# [265]	valid_0's binary_logloss: 0.468107
# [266]	valid_0's binary_logloss: 0.468094
# [267]	valid_0's binary_logloss: 0.468109
# [268]	valid_0's binary_logloss: 0.468111
# [269]	valid_0's binary_logloss: 0.468117
# [270]	valid_0's binary_logloss: 0.468106
# [271]	valid_0's binary_logloss: 0.468116
# [272]	valid_0's binary_logloss: 0.468128
# [273]	valid_0's binary_logloss: 0.468124
# [274]	valid_0's binary_logloss: 0.468092
# [275]	valid_0's binary_logloss: 0.468082
# [276]	valid_0's binary_logloss: 0.468089
# [277]	valid_0's binary_logloss: 0.468065
# [278]	valid_0's binary_logloss: 0.468017
# [279]	valid_0's binary_logloss: 0.468016
# [280]	valid_0's binary_logloss: 0.46803
# [281]	valid_0's binary_logloss: 0.468024
# [282]	valid_0's binary_logloss: 0.46804
# [283]	valid_0's binary_logloss: 0.468022
# [284]	valid_0's binary_logloss: 0.468025
# [285]	valid_0's binary_logloss: 0.468016
# [286]	valid_0's binary_logloss: 0.468003
# [287]	valid_0's binary_logloss: 0.467994
# [288]	valid_0's binary_logloss: 0.46798
# [289]	valid_0's binary_logloss: 0.468008
# [290]	valid_0's binary_logloss: 0.46802
# [291]	valid_0's binary_logloss: 0.46805
# [292]	valid_0's binary_logloss: 0.468052
# [293]	valid_0's binary_logloss: 0.468043
# [294]	valid_0's binary_logloss: 0.468029
# [295]	valid_0's binary_logloss: 0.468034
# [296]	valid_0's binary_logloss: 0.468057
# [297]	valid_0's binary_logloss: 0.468068
# [298]	valid_0's binary_logloss: 0.468068
# [299]	valid_0's binary_logloss: 0.468078
# [300]	valid_0's binary_logloss: 0.468093
# [301]	valid_0's binary_logloss: 0.468095
# [302]	valid_0's binary_logloss: 0.468114
# [303]	valid_0's binary_logloss: 0.4681
# [304]	valid_0's binary_logloss: 0.468113
# [305]	valid_0's binary_logloss: 0.468103
# [306]	valid_0's binary_logloss: 0.468062
# [307]	valid_0's binary_logloss: 0.468046
# [308]	valid_0's binary_logloss: 0.467998
# [309]	valid_0's binary_logloss: 0.468003
# [310]	valid_0's binary_logloss: 0.468033
# [311]	valid_0's binary_logloss: 0.468028
# [312]	valid_0's binary_logloss: 0.468
# [313]	valid_0's binary_logloss: 0.468016
# [314]	valid_0's binary_logloss: 0.468007
# [315]	valid_0's binary_logloss: 0.468031
# [316]	valid_0's binary_logloss: 0.468047
# [317]	valid_0's binary_logloss: 0.468005
# [318]	valid_0's binary_logloss: 0.467976
# [319]	valid_0's binary_logloss: 0.467975
# [320]	valid_0's binary_logloss: 0.467944
# [321]	valid_0's binary_logloss: 0.467934
# [322]	valid_0's binary_logloss: 0.467941
# [323]	valid_0's binary_logloss: 0.467923
# [324]	valid_0's binary_logloss: 0.467907
# [325]	valid_0's binary_logloss: 0.467925
# [326]	valid_0's binary_logloss: 0.467953
# [327]	valid_0's binary_logloss: 0.467983
# [328]	valid_0's binary_logloss: 0.46798
# [329]	valid_0's binary_logloss: 0.467958
# [330]	valid_0's binary_logloss: 0.467943
# [331]	valid_0's binary_logloss: 0.467944
# [332]	valid_0's binary_logloss: 0.467919
# [333]	valid_0's binary_logloss: 0.467899
# [334]	valid_0's binary_logloss: 0.467926
# [335]	valid_0's binary_logloss: 0.467929
# [336]	valid_0's binary_logloss: 0.467921
# [337]	valid_0's binary_logloss: 0.467931
# [338]	valid_0's binary_logloss: 0.467877
# [339]	valid_0's binary_logloss: 0.46788
# [340]	valid_0's binary_logloss: 0.467894
# [341]	valid_0's binary_logloss: 0.4679
# [342]	valid_0's binary_logloss: 0.467925
# [343]	valid_0's binary_logloss: 0.46793
# [344]	valid_0's binary_logloss: 0.467935
# [345]	valid_0's binary_logloss: 0.467941
# [346]	valid_0's binary_logloss: 0.467961
# [347]	valid_0's binary_logloss: 0.467894
# [348]	valid_0's binary_logloss: 0.467873
# [349]	valid_0's binary_logloss: 0.467854
# [350]	valid_0's binary_logloss: 0.467865
# [351]	valid_0's binary_logloss: 0.467893
# [352]	valid_0's binary_logloss: 0.467877
# [353]	valid_0's binary_logloss: 0.46788
# [354]	valid_0's binary_logloss: 0.467875
# [355]	valid_0's binary_logloss: 0.467883
# [356]	valid_0's binary_logloss: 0.467909
# [357]	valid_0's binary_logloss: 0.467923
# [358]	valid_0's binary_logloss: 0.467945
# [359]	valid_0's binary_logloss: 0.467939
# [360]	valid_0's binary_logloss: 0.467949
# [361]	valid_0's binary_logloss: 0.467978
# [362]	valid_0's binary_logloss: 0.467979
# [363]	valid_0's binary_logloss: 0.468002
# [364]	valid_0's binary_logloss: 0.468024
# [365]	valid_0's binary_logloss: 0.468001
# [366]	valid_0's binary_logloss: 0.468005
# [367]	valid_0's binary_logloss: 0.46802
# [368]	valid_0's binary_logloss: 0.468013
# [369]	valid_0's binary_logloss: 0.468007
# [370]	valid_0's binary_logloss: 0.46799
# [371]	valid_0's binary_logloss: 0.467969
# [372]	valid_0's binary_logloss: 0.467989
# [373]	valid_0's binary_logloss: 0.467975
# [374]	valid_0's binary_logloss: 0.467971
# [375]	valid_0's binary_logloss: 0.467979
# [376]	valid_0's binary_logloss: 0.467953
# [377]	valid_0's binary_logloss: 0.467956
# [378]	valid_0's binary_logloss: 0.46796
# [379]	valid_0's binary_logloss: 0.467985
# [380]	valid_0's binary_logloss: 0.467972
# [381]	valid_0's binary_logloss: 0.467984
# [382]	valid_0's binary_logloss: 0.467955
# [383]	valid_0's binary_logloss: 0.467946
# [384]	valid_0's binary_logloss: 0.467954
# [385]	valid_0's binary_logloss: 0.467914
# [386]	valid_0's binary_logloss: 0.467918
# [387]	valid_0's binary_logloss: 0.467903
# [388]	valid_0's binary_logloss: 0.467901
# [389]	valid_0's binary_logloss: 0.467876
# [390]	valid_0's binary_logloss: 0.467902
# [391]	valid_0's binary_logloss: 0.467877
# [392]	valid_0's binary_logloss: 0.467893
# [393]	valid_0's binary_logloss: 0.467875
# [394]	valid_0's binary_logloss: 0.467892
# [395]	valid_0's binary_logloss: 0.467905
# [396]	valid_0's binary_logloss: 0.467916
# [397]	valid_0's binary_logloss: 0.467928
# [398]	valid_0's binary_logloss: 0.46791
# [399]	valid_0's binary_logloss: 0.467908
# [400]	valid_0's binary_logloss: 0.467868
# [401]	valid_0's binary_logloss: 0.467858
# [402]	valid_0's binary_logloss: 0.467874
# [403]	valid_0's binary_logloss: 0.467878
# [404]	valid_0's binary_logloss: 0.467879
# [405]	valid_0's binary_logloss: 0.46786
# [406]	valid_0's binary_logloss: 0.467844
# [407]	valid_0's binary_logloss: 0.467842
# [408]	valid_0's binary_logloss: 0.46784
# [409]	valid_0's binary_logloss: 0.467834
# [410]	valid_0's binary_logloss: 0.467822
# [411]	valid_0's binary_logloss: 0.467825
# [412]	valid_0's binary_logloss: 0.467844
# [413]	valid_0's binary_logloss: 0.467854
# [414]	valid_0's binary_logloss: 0.467879
# [415]	valid_0's binary_logloss: 0.46789
# [416]	valid_0's binary_logloss: 0.467885
# [417]	valid_0's binary_logloss: 0.467872
# [418]	valid_0's binary_logloss: 0.467885
# [419]	valid_0's binary_logloss: 0.467888
# [420]	valid_0's binary_logloss: 0.467883
# [421]	valid_0's binary_logloss: 0.467918
# [422]	valid_0's binary_logloss: 0.467913
# [423]	valid_0's binary_logloss: 0.467922
# [424]	valid_0's binary_logloss: 0.467962
# [425]	valid_0's binary_logloss: 0.467985
# [426]	valid_0's binary_logloss: 0.467961
# [427]	valid_0's binary_logloss: 0.467972
# [428]	valid_0's binary_logloss: 0.467965
# [429]	valid_0's binary_logloss: 0.467997
# [430]	valid_0's binary_logloss: 0.467999
# [431]	valid_0's binary_logloss: 0.468005
# [432]	valid_0's binary_logloss: 0.468011
# [433]	valid_0's binary_logloss: 0.468014
# [434]	valid_0's binary_logloss: 0.468025
# [435]	valid_0's binary_logloss: 0.467987
# [436]	valid_0's binary_logloss: 0.46798
# [437]	valid_0's binary_logloss: 0.467973
# [438]	valid_0's binary_logloss: 0.46798
# [439]	valid_0's binary_logloss: 0.467983
# [440]	valid_0's binary_logloss: 0.468014
# [441]	valid_0's binary_logloss: 0.468026
# [442]	valid_0's binary_logloss: 0.467981
# [443]	valid_0's binary_logloss: 0.467974
# [444]	valid_0's binary_logloss: 0.467995
# [445]	valid_0's binary_logloss: 0.46803
# [446]	valid_0's binary_logloss: 0.468029
# [447]	valid_0's binary_logloss: 0.468031
# [448]	valid_0's binary_logloss: 0.468047
# [449]	valid_0's binary_logloss: 0.468048
# [450]	valid_0's binary_logloss: 0.468049
# [451]	valid_0's binary_logloss: 0.468046
# [452]	valid_0's binary_logloss: 0.468041
# [453]	valid_0's binary_logloss: 0.468054
# [454]	valid_0's binary_logloss: 0.468025
# [455]	valid_0's binary_logloss: 0.468029
# [456]	valid_0's binary_logloss: 0.468026
# [457]	valid_0's binary_logloss: 0.468013
# [458]	valid_0's binary_logloss: 0.468033
# [459]	valid_0's binary_logloss: 0.468055
# [460]	valid_0's binary_logloss: 0.468064
# [461]	valid_0's binary_logloss: 0.468053
# [462]	valid_0's binary_logloss: 0.468058
# [463]	valid_0's binary_logloss: 0.468068
# [464]	valid_0's binary_logloss: 0.468089
# [465]	valid_0's binary_logloss: 0.468077
# [466]	valid_0's binary_logloss: 0.468057
# [467]	valid_0's binary_logloss: 0.468063
# [468]	valid_0's binary_logloss: 0.468062
# [469]	valid_0's binary_logloss: 0.46805
# [470]	valid_0's binary_logloss: 0.468057
# [471]	valid_0's binary_logloss: 0.468066
# [472]	valid_0's binary_logloss: 0.468074
# [473]	valid_0's binary_logloss: 0.468066
# [474]	valid_0's binary_logloss: 0.468074
# [475]	valid_0's binary_logloss: 0.468062
# [476]	valid_0's binary_logloss: 0.468041
# [477]	valid_0's binary_logloss: 0.468048
# [478]	valid_0's binary_logloss: 0.468064
# [479]	valid_0's binary_logloss: 0.468071
# [480]	valid_0's binary_logloss: 0.468074
# [481]	valid_0's binary_logloss: 0.468092
# [482]	valid_0's binary_logloss: 0.468088
# [483]	valid_0's binary_logloss: 0.468121
# [484]	valid_0's binary_logloss: 0.468098
# [485]	valid_0's binary_logloss: 0.468083
# [486]	valid_0's binary_logloss: 0.468099
# [487]	valid_0's binary_logloss: 0.468122
# [488]	valid_0's binary_logloss: 0.468127
# [489]	valid_0's binary_logloss: 0.468152
# [490]	valid_0's binary_logloss: 0.468179
# [491]	valid_0's binary_logloss: 0.468163
# [492]	valid_0's binary_logloss: 0.468181
# [493]	valid_0's binary_logloss: 0.468164
# [494]	valid_0's binary_logloss: 0.468143
# [495]	valid_0's binary_logloss: 0.468165
# [496]	valid_0's binary_logloss: 0.468178
# [497]	valid_0's binary_logloss: 0.468181
# [498]	valid_0's binary_logloss: 0.468163
# [499]	valid_0's binary_logloss: 0.468174
# [500]	valid_0's binary_logloss: 0.468169
# [501]	valid_0's binary_logloss: 0.468146
# [502]	valid_0's binary_logloss: 0.468147
# [503]	valid_0's binary_logloss: 0.468158
# [504]	valid_0's binary_logloss: 0.468142
# [505]	valid_0's binary_logloss: 0.468136
# [506]	valid_0's binary_logloss: 0.468149
# [507]	valid_0's binary_logloss: 0.468127
# [508]	valid_0's binary_logloss: 0.468134
# [509]	valid_0's binary_logloss: 0.468142
# [510]	valid_0's binary_logloss: 0.468168
# Early stopping, best iteration is:
# [410]	valid_0's binary_logloss: 0.467822
# [Info]: Model is predicting the Data ...
#
# [Info]: Outputs are saved under shekhar_submission.csv file.
